# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on One-to-Many and Many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data including Many-to-Many relationships
# - Write queries that make use of Join Tables

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code here
import sqlite3
import pandas as pd

conn = sqlite3.connect('data.sqlite')
cursor = conn.cursor()

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all of the customers. For each customer return a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
cursor.execute('''SELECT orderNumber, orderDate, status FROM orders;''').fetchall()
# Out:
# [('10100', '2003-01-06', 'Shipped'),
#  ('10101', '2003-01-09', 'Shipped'),
#  ('10102', '2003-01-10', 'Shipped'),
#  ('10103', '2003-01-29', 'Shipped'),
#  ('10104', '2003-01-31', 'Shipped'),
#  ('10105', '2003-02-11', 'Shipped'),
#  ('10106', '2003-02-17', 'Shipped'),
#  ('10107', '2003-02-24', 'Shipped'),
#  ('10108', '2003-03-03', 'Shipped'),
#  ('10109', '2003-03-10', 'Shipped'),
#  ('10110', '2003-03-18', 'Shipped'),
#  ('10111', '2003-03-25', 'Shipped'),
#  ('10112', '2003-03-24', 'Shipped'),
#  ('10113', '2003-03-26', 'Shipped'),
#  ('10114', '2003-04-01', 'Shipped'),
#  ('10115', '2003-04-04', 'Shipped'),
#  ('10116', '2003-04-11', 'Shipped'),
#  ('10117', '2003-04-16', 'Shipped'),
#  ('10118', '2003-04-21', 'Shipped'),
#  ('10119', '2003-04-28', 'Shipped'),
#  ('10120', '2003-04-29', 'Shipped'),
#  ('10121', '2003-05-07', 'Shipped'),
#  ('10122', '2003-05-08', 'Shipped'),
#  ('10123', '2003-05-20', 'Shipped'),
#  ('10124', '2003-05-21', 'Shipped'),
# ...

# %% [markdown]
# ## Orders and their Order Details (another One-to-Many join)
#
# Return a list of orders. For each order return a record for each order detail within the order.

# %%
# Your code here
cursor.execute('''SELECT * FROM orderdetails;''').fetchall()
# Out:
# [('10100', 'S18_1749', '30', '136.00', '3'),
#  ('10100', 'S18_2248', '50', '55.09', '2'),
#  ('10100', 'S18_4409', '22', '75.46', '4'),
#  ('10100', 'S24_3969', '49', '35.29', '1'),
#  ('10101', 'S18_2325', '25', '108.06', '4'),
#  ('10101', 'S18_2795', '26', '167.06', '1'),
#  ('10101', 'S24_1937', '45', '32.53', '3'),
#  ('10101', 'S24_2022', '46', '44.35', '2'),
#  ('10102', 'S18_1342', '39', '95.55', '2'),
#  ('10102', 'S18_1367', '41', '43.13', '1'),
#  ('10103', 'S10_1949', '26', '214.30', '11'),
#  ('10103', 'S10_4962', '42', '119.67', '4'),
#  ('10103', 'S12_1666', '27', '121.64', '8'),
#  ('10103', 'S18_1097', '35', '94.50', '10'),
#  ('10103', 'S18_2432', '22', '58.34', '2'),
#  ('10103', 'S18_2949', '27', '92.19', '12'),
#  ('10103', 'S18_2957', '35', '61.84', '14'),
#  ('10103', 'S18_3136', '25', '86.92', '13'),
#  ('10103', 'S18_3320', '46', '86.31', '16'),
#  ('10103', 'S18_4600', '36', '98.07', '5'),
#  ('10103', 'S18_4668', '41', '40.75', '9'),
# ...

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of the orders with the the order information, and allthe product information for each product in the order.

# %%
# Your code here
cursor.execute('''SELECT * FROM orderdetails o
JOIN products p 
ON p.productCode = o.productCode
GROUP BY o.orderNumber''').fetchall()
# Out:
# [('10100',
#   'S24_3969',
#   '49',
#   '35.29',
#   '1',
#   'S24_3969',
#   '1936 Mercedes Benz 500k Roadster',
#   'Vintage Cars',
#   '1:24',
#   'Red Start Diecast',
#   'This model features grille-mounted chrome horn, lift-up louvered hood, fold-down rumble seat, working steering system and rubber wheels. Color black.',
#   '2081',
#   '21.75',
#   '41.03'),
#  ('10101',
#   'S24_2022',
#   '46',
#   '44.35',
#   '2',
#   'S24_2022',
#   '1938 Cadillac V-16 Presidential Limousine',
#   'Vintage Cars',
#   '1:24',
#   'Classic Metal Creations',
#   'This 1:24 scale precision die cast replica of the 1938 Cadillac V-16 Presidential Limousine has all the details of the original, from the flags on the front to an opening back seat compartment complete with telephone and rifle. Features factory baked-enamel black finish, hood goddess ornament, working jump seats.',
#   '2847',
#   '20.61',
#   '44.80'),
#  ('10102',
#   'S18_1367',
#   '41',
#   '43.13',
#   '1',
#   'S18_1367',
# ...

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on One-to-Many and Many-to-many relationships!
